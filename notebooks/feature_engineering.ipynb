# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('train.csv')
df[df['Gender'].isnull()].sample(5)
# Out:
#      Unnamed: 0  Type                             Name  Age  Gender  \
# 362          27     1                              NaN    2     NaN
# 494         826     1  Tank & Zorro (Urgent Adoption!)  120     NaN
# 919         918     2                          Kitties    1     NaN
# 130         878     2                        3 Kitties    3     NaN
# 65          942     1                          Mitchie    3     NaN
#
#      MaturitySize  FurLength  Vaccinated  Dewormed  Sterilized  ...  \
# 362           2.0          1           2         1           2  ...
# 494           3.0          2           1         1           1  ...
# 919           2.0          1           2         2           2  ...
# 130           1.0          1           2         2           2  ...
# 65            2.0          1           3         1           2  ...
#
#                                            Description      PetID  PhotoAmt  \
# 362  Very Cute.....Very Healthy........taught and k...  22a0baf52       3.0
# 494  Our two adult dogs are available for adoption ...  ef7bdaf3a       3.0
# 919  The kittens and their mother are quite healthy...  ebff4722c       6.0
# 130  There are three kittens I'm putting up for ado...  8867ee30a       6.0
# 65   Mitchie is a cute little intelligent 3 month o...  979bab13e       3.0
#
#      ColorName_x ColorName_y  ColorName          BreedName_x  \
# 362        Brown      Yellow        NaN          Mixed Breed
# 494        Black       Brown        NaN   Labrador Retriever
# 919        Black        Gray        NaN              Persian
# 130        Brown        Gray        NaN  Domestic Short Hair
# 65         Cream        Gray        NaN                Husky
#
#               BreedName_y   StateName_x AdoptionSpeed
# 362           Mixed Breed      Selangor             2
# 494               Harrier      Selangor             0
# 919  Domestic Medium Hair  Kuala Lumpur             1
# 130   Domestic Short Hair  Kuala Lumpur             1
# 65                 Poodle  Kuala Lumpur             0
#
# [5 rows x 26 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0         Type          Age       Gender  MaturitySize  \
# count  1220.000000  1220.000000  1220.000000  1160.000000   1096.000000
# mean    679.300000     1.562295     8.767213     2.101724      1.864051
# std     390.022296     0.496308    16.287005     0.748883      0.532714
# min       0.000000     1.000000     0.000000     1.000000      1.000000
# 25%     342.750000     1.000000     2.000000     2.000000      2.000000
# 50%     680.500000     2.000000     3.000000     2.000000      2.000000
# 75%    1015.250000     2.000000     8.000000     3.000000      2.000000
# max    1355.000000     2.000000   212.000000     3.000000      4.000000
#
#          FurLength   Vaccinated     Dewormed   Sterilized       Health  \
# count  1220.000000  1220.000000  1220.000000  1220.000000  1220.000000
# mean      1.585246     1.770492     1.556557     1.943443     1.023770
# std       0.631504     0.619440     0.661305     0.553235     0.162806
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000     2.000000     1.000000
# 50%       2.000000     2.000000     1.000000     2.000000     1.000000
# 75%       2.000000     2.000000     2.000000     2.000000     1.000000
# max       3.000000     3.000000     3.000000     3.000000     3.000000
#
#           Quantity          Fee         State     VideoAmt     PhotoAmt  \
# count  1220.000000  1220.000000   1220.000000  1220.000000  1220.000000
# mean      2.279508    19.658197  41345.639344     0.083607     4.740164
# std       2.089013    59.898386     32.266188     0.502228     4.068187
# min       1.000000     0.000000  41324.000000     0.000000     0.000000
# 25%       1.000000     0.000000  41326.000000     0.000000     2.000000
# 50%       1.000000     0.000000  41326.000000     0.000000     4.000000
# 75%       3.000000     0.000000  41401.000000     0.000000     5.000000
# max      20.000000   750.000000  41401.000000     8.000000    30.000000
#
#        AdoptionSpeed
# count    1220.000000
# mean        1.022951
# std         0.725351
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Type', 'Name', 'Age', 'Gender', 'MaturitySize',
#        'FurLength', 'Vaccinated', 'Dewormed', 'Sterilized', 'Health',
#        'Quantity', 'Fee', 'State', 'RescuerID', 'VideoAmt', 'Description',
#        'PetID', 'PhotoAmt', 'ColorName_x', 'ColorName_y', 'ColorName',
#        'BreedName_x', 'BreedName_y', 'StateName_x', 'AdoptionSpeed'],
#       dtype='object')

# %% [markdown]
# ## Nan values ##

# %%
def count_nan(data: pd.DataFrame):
    missing = list()
    for x in data.columns:
        if data[x].isnull().sum() != 0:
            print(x, data[x].isnull().sum())
            missing.append(x)

count_nan(df)
# Out:
# Name 101
# Gender 60
# MaturitySize 124
# ColorName 187
# BreedName_x 131
# BreedName_y 121

# %% [markdown]
# - Drop unnecessary fields (Dewormed has high correlation level with Vaccinated)

# %%
ds = df.drop(['Unnamed: 0', 'Name', 'RescuerID', 'PetID', 'Dewormed', 'Description'], axis=1)

# %% [markdown]
# - Drop rows without gender, because we can't make up a gender and it's less than 5% of all rows

# %%
ds.dropna(how='any', subset=['Gender'], inplace=True)
ds[['Gender']].isnull().sum()
ds['Gender'] = ds['Gender'].astype(float)

# %% [markdown]
# - Nan values of breed fill with 'Unknown'

# %%
ds[['BreedName_x', 'BreedName_y']] = ds[['BreedName_x', 'BreedName_y']].fillna('Unknown')
ds[['BreedName_x', 'BreedName_y']].isnull().sum()
# Out:
# BreedName_x    0
# BreedName_y    0
# dtype: int64

# %% [markdown]
# - Mode fill of MaturitySize and ColorName

# %%
def mode_fill(data, columns):
    for col in columns:
        data[col] = data[col].fillna(data[col].mode()[0])
    return data

mode_fill(ds, ['MaturitySize', 'ColorName'])
ds[['MaturitySize', 'ColorName']].isnull().sum()
# Out:
# MaturitySize    0
# ColorName       0
# dtype: int64

# %% [markdown]
# - Check the empty values

# %%
ds.isnull().sum()
# Out:
# Type             0
# Age              0
# Gender           0
# MaturitySize     0
# FurLength        0
# Vaccinated       0
# Sterilized       0
# Health           0
# Quantity         0
# Fee              0
# State            0
# VideoAmt         0
# PhotoAmt         0
# ColorName_x      0
# ColorName_y      0
# ColorName        0
# BreedName_x      0
# BreedName_y      0
# StateName_x      0
# AdoptionSpeed    0
# dtype: int64

# %% [markdown]
# ## Categorical data encoding ##
# **One Hot Encoding**

# %%
encoder = OneHotEncoder(categories='auto',
                       drop='first',
                       sparse_output=False)
encoder.fit(ds[['ColorName_x', 'ColorName_y', 'ColorName', 'StateName_x']])
# Out:
# OneHotEncoder(drop='first', sparse_output=False)

# %%
encoder.categories_
# Out:
# [array(['Black', 'Brown', 'Cream', 'Golden', 'Yellow'], dtype=object),
#  array(['Brown', 'Cream', 'Golden', 'Gray', 'Yellow'], dtype=object),
#  array(['Cream', 'Golden', 'Gray', 'White', 'Yellow'], dtype=object),
#  array(['Johor', 'Kedah', 'Kelantan', 'Kuala Lumpur', 'Melaka',
#         'Negeri Sembilan', 'Pahang', 'Perak', 'Pulau Pinang', 'Selangor',
#         'Terengganu'], dtype=object)]

# %%
encoded_data = encoder.transform(ds[['ColorName_x', 'ColorName_y', 'ColorName', 'StateName_x']])

encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['ColorName_x', 'ColorName_y', 'ColorName', 'StateName_x']))

ds = ds.drop(columns=['ColorName_x', 'ColorName_y', 'ColorName', 'StateName_x'])
ds = pd.concat([ds.reset_index(drop=True), encoded_df.reset_index(drop=True)], axis=1)

# %% [markdown]
# **Target Encoding**

# %%
breed_x_target_mean = ds.groupby('BreedName_x')['AdoptionSpeed'].mean()
breed_y_target_mean = ds.groupby('BreedName_y')['AdoptionSpeed'].mean()
ds['BreedName_x'] = ds['BreedName_x'].map(breed_x_target_mean)
ds['BreedName_y'] = ds['BreedName_y'].map(breed_y_target_mean)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Type                         1160 non-null   int64
#  1   Age                          1160 non-null   int64
#  2   Gender                       1160 non-null   float64
#  3   MaturitySize                 1160 non-null   float64
#  4   FurLength                    1160 non-null   int64
#  5   Vaccinated                   1160 non-null   int64
#  6   Sterilized                   1160 non-null   int64
#  7   Health                       1160 non-null   int64
#  8   Quantity                     1160 non-null   int64
#  9   Fee                          1160 non-null   int64
#  10  State                        1160 non-null   int64
#  11  VideoAmt                     1160 non-null   int64
#  12  PhotoAmt                     1160 non-null   float64
#  13  BreedName_x                  1160 non-null   float64
#  14  BreedName_y                  1160 non-null   float64
#  15  AdoptionSpeed                1160 non-null   int64
#  16  ColorName_x_Brown            1160 non-null   float64
#  17  ColorName_x_Cream            1160 non-null   float64
#  18  ColorName_x_Golden           1160 non-null   float64
#  19  ColorName_x_Yellow           1160 non-null   float64
#  20  ColorName_y_Cream            1160 non-null   float64
#  21  ColorName_y_Golden           1160 non-null   float64
#  22  ColorName_y_Gray             1160 non-null   float64
#  23  ColorName_y_Yellow           1160 non-null   float64
#  24  ColorName_Golden             1160 non-null   float64
#  25  ColorName_Gray               1160 non-null   float64
#  26  ColorName_White              1160 non-null   float64
#  27  ColorName_Yellow             1160 non-null   float64
#  28  StateName_x_Kedah            1160 non-null   float64
#  29  StateName_x_Kelantan         1160 non-null   float64
#  30  StateName_x_Kuala Lumpur     1160 non-null   float64
#  31  StateName_x_Melaka           1160 non-null   float64
#  32  StateName_x_Negeri Sembilan  1160 non-null   float64
#  33  StateName_x_Pahang           1160 non-null   float64
#  34  StateName_x_Perak            1160 non-null   float64
#  35  StateName_x_Pulau Pinang     1160 non-null   float64
#  36  StateName_x_Selangor         1160 non-null   float64
#  37  StateName_x_Terengganu       1160 non-null   float64
# dtypes: float64(27), int64(11)
# memory usage: 344.5 KB

# %% [markdown]
# ## Scaling ##

# %%
y = ds['AdoptionSpeed']
X = ds.drop('AdoptionSpeed', axis = 1)

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X))

# %%
X['AdoptionSpeed'] = y
X.to_csv('pets_data.csv', index=False)

# %%
X.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.126969 -0.475739  1.200005  0.249867 -0.931648  0.359706  0.095490
# 1 -1.126969 -0.349542  1.200005  0.249867 -0.931648  1.983281  1.911365
# 2  0.887336 -0.538837  1.200005  0.249867 -0.931648  0.359706  0.095490
# 3 -1.126969 -0.475739 -1.471792 -1.721875  0.648340  0.359706  1.911365
# 4  0.887336 -0.349542 -0.135893  0.249867  2.228329  0.359706  0.095490
#
#           7         8         9  ...        28       29        30        31  \
# 0 -0.146889  0.335676 -0.320023  ... -0.029374 -0.57735 -0.077917 -0.125546
# 1 -0.146889 -0.139183 -0.320023  ... -0.029374 -0.57735 -0.077917 -0.125546
# 2 -0.146889  0.810534 -0.320023  ... -0.029374 -0.57735 -0.077917 -0.125546
# 3 -0.146889 -0.614041 -0.320023  ... -0.029374 -0.57735 -0.077917 -0.125546
# 4 -0.146889 -0.614041 -0.320023  ... -0.029374 -0.57735 -0.077917 -0.125546
#
#          32        33        34        35        36  AdoptionSpeed
# 0 -0.058824 -0.157274 -0.216637  0.807726 -0.058824              1
# 1 -0.058824 -0.157274 -0.216637  0.807726 -0.058824              1
# 2 -0.058824 -0.157274 -0.216637  0.807726 -0.058824              1
# 3 -0.058824 -0.157274 -0.216637  0.807726 -0.058824              1
# 4 -0.058824 -0.157274 -0.216637  0.807726 -0.058824              1
#
# [5 rows x 38 columns]
